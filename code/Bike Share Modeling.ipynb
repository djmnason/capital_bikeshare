# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bike = pd.read_csv("bikeshare_data.csv", index_col = 0, parse_dates = ["Start_day"])
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
bike.head()
# Out:
#    Start_day  Start_hour  Arrivals  Departures  Diff  Start_station_number  \
# 0 2019-11-26           9       2.0         0.0   2.0                     0
# 1 2019-11-27           9       1.0         0.0   1.0                     0
# 2 2019-11-28          16       1.0         0.0   1.0                     0
# 3 2019-11-30          23       1.0         0.0   1.0                     0
# 4 2019-12-01          16       0.0         1.0  -1.0                     0
#
#     Start_station   Latitude  Longitude  Capacity     Region_name  cumu_sum  \
# 0  22nd & H St NW  38.898925 -77.048852      17.0  Washington, DC       2.0
# 1  22nd & H St NW  38.898925 -77.048852      17.0  Washington, DC       3.0
# 2  22nd & H St NW  38.898925 -77.048852      17.0  Washington, DC       4.0
# 3  22nd & H St NW  38.898925 -77.048852      17.0  Washington, DC       5.0
# 4  22nd & H St NW  38.898925 -77.048852      17.0  Washington, DC       4.0
#
#    percent_full  weekend_flag  TAVG  TMAX  TMIN  PRCP  SNOW  Holiday
# 0      0.117647             0    48    62    38  0.00   0.0    False
# 1      0.176471             0    51    58    44  0.01   0.0    False
# 2      0.235294             0    50    54    43  0.00   0.0     True
# 3      0.294118             1    43    46    41  0.00   0.0    False
# 4      0.235294             1    43    46    40  0.50   0.0    False

# %%
bike.isnull().sum()
# Out:
# Start_day                    0
# Start_hour                   0
# Arrivals                     0
# Departures                   0
# Diff                         0
# Start_station_number         0
# Start_station                0
# Latitude                240095
# Longitude               240095
# Capacity                240095
# Region_name             240095
# cumu_sum                     0
# percent_full            240095
# weekend_flag                 0
# TAVG                         0
# TMAX                         0
# TMIN                         0
# PRCP                         0
# SNOW                         0
# Holiday                      0
# dtype: int64

# %%
bike.shape
# Out:
# (1786026, 20)

# %%
bike.dropna(inplace = True)
bike.shape
# Out:
# (1545931, 20)

# %% [markdown]
# ## data cleaning
#
# vars: availability, station, hour, month, day of week, weekend, in DC, tmp vars, holiday

# %%
bike.columns
# Out:
# Index(['Start_day', 'Start_hour', 'Arrivals', 'Departures', 'Diff',
#        'Start_station_number', 'Start_station', 'Latitude', 'Longitude',
#        'Capacity', 'Region_name', 'cumu_sum', 'percent_full', 'weekend_flag',
#        'TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'Holiday'],
#       dtype='object')

# %%
bike.dtypes
# Out:
# Start_day               datetime64[ns]
# Start_hour                       int64
# Arrivals                       float64
# Departures                     float64
# Diff                           float64
# Start_station_number             int64
# Start_station                   object
# Latitude                       float64
# Longitude                      float64
# Capacity                       float64
# Region_name                     object
# cumu_sum                       float64
# percent_full                   float64
# weekend_flag                     int64
# TAVG                             int64
# TMAX                             int64
# TMIN                             int64
# PRCP                           float64
# SNOW                           float64
# Holiday                           bool
# dtype: object

# %%
plt.figure(figsize=(12,12))
ax = plt.axes()
corr = bike[['Start_hour', 'Arrivals', 'Departures', 'Diff', 'Latitude', 'Longitude', 'Capacity', 'percent_full', 'TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW']].corr().round(2)
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(15,15))
sns.heatmap(corr, mask=mask, annot = True, square=True, ax = ax)
ax.set_title("No clear linear relationship between variables besides temperature and trip variables")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-278-d8da5d8fdbbc> in <module>
#       1 plt.figure(figsize=(12,12))
#       2 ax = plt.axes()
# ----> 3 corr = bike[['Start_hour', 'Arrivals', 'Departures', 'Diff', 'Latitude', 'Longitude', 'Capacity', 'percent_full', 'TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW']].corr().round(2)
#       4 mask = np.zeros_like(corr)
#       5 mask[np.triu_indices_from(mask)] = True
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['Diff', 'TAVG', 'Arrivals', 'TMIN', 'PRCP', 'Longitude', 'Latitude', 'Start_hour', 'Departures', 'SNOW', 'TMAX', 'Capacity'] not in index"

# %%
## dropping the redundant information
var = ["Start_day", "Start_hour", "Start_station", "Longitude", "Latitude", "Region_name", "percent_full", "weekend_flag", "TAVG", "TMAX", "TMIN", "PRCP", "SNOW", "Holiday"]
# eda data
bike = bike[var]

# %%
## cleaning up names
bike.columns = ["_".join(col.split(" ")).lower() for col in bike.columns]
bike.rename({"start_day":"date", "start_hour":"hour", "start_station":"station", "weekend_flag":"weekend"}, axis = 1, inplace = True)

# %% [markdown]
# ## defining variables

# %%
bike['weekday'] = bike.date.dt.dayofweek
# bike.loc[bike['weekday'] == 0, 'weekday'] = 'Mon'
# bike.loc[bike['weekday'] == 1, 'weekday'] = 'Tue'
# bike.loc[bike['weekday'] == 2, 'weekday'] = 'Wed'
# bike.loc[bike['weekday'] == 3, 'weekday'] = 'Thu'
# bike.loc[bike['weekday'] == 4, 'weekday'] = 'Fri'
# bike.loc[bike['weekday'] == 5, 'weekday'] = 'Sat'
# bike.loc[bike['weekday'] == 6, 'weekday'] = 'Sun'
# bike['weekday'] = bike['weekday'].astype("category")

# %%
# defining variables
bike['month'] = bike.date.dt.month

# %%
bike['in_dc'] = bike.region_name.apply(lambda x: 1 if x == "Washington, DC" else 0)

# %%
bike['holiday'] = bike.holiday.apply(lambda x: 1 if x == True else 0)

# %%
bike.head()
# Out:
#         date  hour         station  longitude   latitude     region_name  \
# 0 2019-11-26     9  22nd & H St NW -77.048852  38.898925  Washington, DC
# 1 2019-11-27     9  22nd & H St NW -77.048852  38.898925  Washington, DC
# 2 2019-11-28    16  22nd & H St NW -77.048852  38.898925  Washington, DC
# 3 2019-11-30    23  22nd & H St NW -77.048852  38.898925  Washington, DC
# 4 2019-12-01    16  22nd & H St NW -77.048852  38.898925  Washington, DC
#
#    percent_full  weekend  tavg  tmax  tmin  prcp  snow  holiday  weekday  \
# 0      0.117647        0    48    62    38  0.00   0.0        0        1
# 1      0.176471        0    51    58    44  0.01   0.0        0        2
# 2      0.235294        0    50    54    43  0.00   0.0        1        3
# 3      0.294118        1    43    46    41  0.00   0.0        0        5
# 4      0.235294        1    43    46    40  0.50   0.0        0        6
#
#    month  in_dc
# 0     11      1
# 1     11      1
# 2     11      1
# 3     11      1
# 4     12      1

# %%
bike["station"] = bike["station"].astype("category")

# %% [markdown]
# ## regression version of modeling
#
# First, we try to model using only the response variable (% availability). Using this information could help vendors identify roughly what percentage of bikes that are expected to be at a given station at a given point in time.

# %%
# relocating column to front before test/train split
bike.reset_index(inplace=True, drop = True)
tmp = bike.pop('percent_full')
bike.insert(0, tmp.name, tmp)
del tmp

# %%
bike.set_index('station', inplace = True)
bike.head()
# Out:
#                 percent_full       date  hour  longitude   latitude  \
# station
# 22nd & H St NW      0.117647 2019-11-26     9 -77.048852  38.898925
# 22nd & H St NW      0.176471 2019-11-27     9 -77.048852  38.898925
# 22nd & H St NW      0.235294 2019-11-28    16 -77.048852  38.898925
# 22nd & H St NW      0.294118 2019-11-30    23 -77.048852  38.898925
# 22nd & H St NW      0.235294 2019-12-01    16 -77.048852  38.898925
#
#                    region_name  weekend  tavg  tmax  tmin  prcp  snow  \
# station
# 22nd & H St NW  Washington, DC        0    48    62    38  0.00   0.0
# 22nd & H St NW  Washington, DC        0    51    58    44  0.01   0.0
# 22nd & H St NW  Washington, DC        0    50    54    43  0.00   0.0
# 22nd & H St NW  Washington, DC        1    43    46    41  0.00   0.0
# 22nd & H St NW  Washington, DC        1    43    46    40  0.50   0.0
#
#                 holiday  weekday  month  in_dc
# station
# 22nd & H St NW        0        1     11      1
# 22nd & H St NW        0        2     11      1
# 22nd & H St NW        1        3     11      1
# 22nd & H St NW        0        5     11      1
# 22nd & H St NW        0        6     12      1

# %%
# dropping observations in model fitting due to insufficient sample size (less than 30 for testing data)
exclude = bike.groupby(bike.index)['percent_full'].count().sort_values()[bike.groupby(bike.index)['percent_full'].count().sort_values() < 30/.3].index.tolist()
exclude
# Out:
# ['Ridge Rd Community Center',
#  'Fort Stanton Rec Center',
#  'Valley Ave & Wheeler Rd SE',
#  'Kenilworth Terrace & Hayes St. NE',
#  'National Harbor Carousel',
#  'Capitol Heights Metro',
#  'Shady Grove Hospital',
#  'Campus Commons',
#  'Southern Ave Metro',
#  'Reston Regional Library',
#  'Joliet St & MLK Ave SW/Bald Eagle Rec Ctr',
#  'Wheaton Library & Community Rec Center',
#  'Key West Ave & Great Seneca Hwy']

# %%
bike.shape
# Out:
# (1545931, 16)

# %%
bike.index.nunique()
# Out:
# 488

# %%
len(set(bike.index.unique()).difference(set(exclude)))
# Out:
# 475

# %%
c = list(set(bike.index.unique()).difference(set(exclude)))
len(c)
# Out:
# 475

# %%
c
# Out:
# ['Jones Branch & Westbranch Dr',
#  'Pooks Hill Rd & Linden Ave',
#  'Montello Ave & Holbrook Terr NE',
#  'Eastern Market / 7th & North Carolina Ave SE',
#  '18th & Monroe St NE',
#  '15th & F St NE',
#  'Sunset Hills & Old Reston Ave',
#  '48th Pl & MacArthur Blvd NW',
#  '8th & F St NE',
#  'Falls Church City Hall / Park Ave & Little Falls St',
#  '23rd & M St NW',
#  '20th & E St NW',
#  'United Medical Center',
#  'Crystal Dr & 15th St S',
#  'North Shore Dr & Village Rd',
#  'Sunset Hills Rd & Isaac Newton Square',
#  '8th & K St NE',
#  'Mississippi Ave & 19th St SE / THEARC',
#  'Mount Vernon Ave & Kennedy St',
#  'White Flint Metro',
#  'Good Hope Rd & MLK Ave SE',
#  'Alabama & MLK Ave SE',
#  'Maine Ave & 9th St SW',
#  '9th & Upshur St NW',
#  'Frederick Ave & Horners Ln',
#  '18th & R St NW',
#  '7th St & Massachusetts Ave NE',
#  "Prince George's Plaza Metro",
#  '4th St & Madison Dr NW',
#  'Tysons Corner Station',
#  '13th & H St NE',
#  'Crystal Dr & 27th St S',
#  'Neal St & Trinidad Ave NE',
#  'Roosevelt Island',
#  'Harvard St & Adams Mill Rd NW',
#  'The Mall at Prince Georges',
#  'US Dept of State / Virginia Ave & 21st St NW',
#  'Ward Circle / American University',
#  'Veterans Pl & Pershing Dr ',
#  '1st & M St NE',
#  '2nd St & Massachusetts Ave NE',
#  "L'Enfant Plaza / 7th & C St SW",
#  'Randle Circle & Minnesota Ave SE',
#  'Benning Rd & East Capitol St NE / Benning Rd Metro',
#  'Riverdale Park Town Center',
#  '3rd & G St SE',
#  '37th & O St NW / Georgetown University',
#  'Fallsgrove Blvd & Fallsgrove Dr',
#  '11th & C St SE',
#  'Smithsonian-National Mall / Jefferson Dr & 12th St SW',
#  'Reston Pkwy & Spectrum Dr',
#  'King Farm Blvd & Piccard Dr',
#  'Columbia & Ontario Rd NW',
#  'Ballenger Ave & Dulaney St',
#  'Hains Point/Buckeye & Ohio Dr SW',
#  'Rockville Metro East',
#  'Westpark & Jones Branch Dr',
#  '21st & I St NW',
#  'Maryland Ave & E St NE',
#  '3000 Connecticut Ave NW / National Zoo',
#  '1301 McCormick Dr / Wayne K. Curry Admin Bldg',
#  'Sunset Hills Rd & Discovery Square',
#  'Fairfax Dr & Wilson Blvd',
#  'Washington & Independence Ave SW/HHS',
#  'Traville Gateway Dr & Gudelsky Dr',
#  'North Shore & Cameron Crescent Dr/Crescent Apartments',
#  'Washington Blvd & 7th St N',
#  'Westover Library / Washington Blvd & N McKinley Rd',
#  'Wisconsin Ave & Ingomar St NW',
#  'Lincoln Memorial',
#  'Connecticut Ave & Newark St NW / Cleveland Park',
#  'Georgia Ave & Emerson St NW',
#  'E Montgomery Ave & Maryland Ave',
#  'Mount Vernon Ave & Four Mile Run Park',
#  "10th St & L'Enfant Plaza SW",
#  '8th & East Capitol St NE',
#  '5th St & Massachusetts Ave NW',
#  '34th & Water St NW',
#  'Clarendon Blvd & N Fillmore St',
#  'Washington Blvd & N Frederick St',
#  'Town Center Pkwy & Sunset Hills Rd',
#  'Gravelly Point',
#  'New Jersey Ave & N St NW/Dunbar HS',
#  '19th & G St NW',
#  '19th St & Constitution Ave NW',
#  '4th & D St NW / Judiciary Square',
#  '47th & Elm St',
#  'Wiehle Ave & Reston Station Blvd',
#  '12th & U St NW',
#  '13th & E St SE',
#  '5th & F St NW',
#  '3rd St & Riggs Rd NE',
#  'Lincoln Rd & Seaton Pl NE/Harry Thomas Rec Center',
#  '4th & E St SW',
#  'Carroll & Westmoreland Ave',
#  'John McCormack Dr & Michigan Ave NE',
#  'Twinbrook Metro',
#  '8th & O St NW',
#  '10th St & Constitution Ave NW',
#  'Westpark & Park Run Dr',
#  '13th St & Eastern Ave',
#  'Medical Center Dr & Key West Ave',
#  'Norfolk & Rugby Ave',
#  'W Broad St & Little Falls St',
#  'Crystal Dr & 20th St S',
#  '14th & Luzon St NW',
#  '23rd & E St NW ',
#  '7th & F St NW / National Portrait Gallery',
#  '3rd & M St NE',
#  'East West Hwy & Blair Mill Rd',
#  '16th & Irving St NW',
#  'Corporate Blvd & Omega Dr',
#  '39th & Calvert St NW / Stoddert',
#  'Old Georgetown Rd & Southwick St',
#  'West Hyattsville Metro',
#  '18th & New Hampshire Ave NW',
#  '15th & M St NW',
#  'New York Ave & Hecht Ave NE',
#  '12th & Newton St NE',
#  'King Farm Blvd & Pleasant Dr',
#  '14th & Rhode Island Ave NW',
#  'Georgia Ave & Spring St',
#  'Pennsylvania Ave & Park Ave',
#  'Park Run & Onyx Dr',
#  'Connecticut Ave & Yuma St NW',
#  'Library St & Freedom Dr',
#  '1st & Rhode Island Ave NW',
#  'Kennedy Center',
#  'Columbia Rd & Georgia Ave NW',
#  'Lee Center',
#  '14th & Newton St NW',
#  'Perry & 35th St',
#  '15th & K St NW',
#  'Towers Crescent Dr & Tysons One Pl',
#  'Jefferson Memorial',
#  'Van Ness Metro / UDC',
#  '4th & M St SE',
#  'Hamlin & 7th St NE',
#  'Battery Ln & Trolley Trail',
#  'Fenton St & Ellsworth Dr ',
#  'Lamont & Mt Pleasant NW',
#  'Calvert & Biltmore St NW',
#  'Oxon Hill Park & Ride',
#  '19th & East Capitol St SE',
#  'Greensboro & Pinnacle Dr',
#  'Riggs Rd & East West Hwy',
#  '12th & L St NW',
#  '34th St & Wisconsin Ave NW',
#  '7th & R St NW / Shaw Library',
#  'Connecticut Ave & Tilden St NW',
#  'Wilson Blvd & N Uhle St',
#  '4th & C St SW',
#  '10th & Florida Ave NW',
#  '20th St & Florida Ave NW',
#  'Bethesda Ave & Arlington Rd',
#  "Independence Ave & L'Enfant Plaza SW/DOE",
#  'Fenton St & New York Ave ',
#  'South Capitol & Atlantic St SW',
#  '8th & H St NW',
#  'Woodmont Ave & Strathmore St',
#  'Potomac Ave & 8th St SE',
#  'Takoma Metro',
#  'Columbus Ave & Tribeca St',
#  'Reston YMCA',
#  'King St Metro North / Cameron St',
#  '11th & Park Rd NW',
#  'Livingston Rd & 3rd St SE',
#  '13th & D St NE',
#  '8th & Eye St SE / Barracks Row',
#  'Crystal Dr & 23rd St S',
#  'Fenton St & Gist Ave',
#  '17th & K St NW',
#  'Grandview & Blueridge Ave',
#  'Wilson Blvd & N Quincy St',
#  'Convention Center / 7th & M St NW',
#  'Rhode Island Ave Metro',
#  'New Hampshire & Gallatin St NW',
#  'Anacostia Park',
#  'Arlington Blvd & N Queen St',
#  '18th & C St NW',
#  'Columbia Pike & S Walter Reed Dr',
#  'Eisenhower Ave & Mill Race Ln',
#  'Clarendon Blvd & Pierce St',
#  'Mount Vernon Ave & E Del Ray Ave',
#  'C & O Canal & Wisconsin Ave NW',
#  'Arlington Blvd & Fillmore St',
#  '22nd St & Constitution Ave NW',
#  'Wilson Blvd & N Illinois St ',
#  'Deanwood Rec Center',
#  'Wisconsin Ave & Newark St NW',
#  '10th & K St NW',
#  '10th & E St NW',
#  'N Oak St & W Broad St',
#  '7th & K St NW',
#  '17th & Corcoran St NW',
#  'Northwestern High School',
#  'Dunn Loring Metro',
#  'Anacostia Library',
#  'River Rd & Landy Ln',
#  'Executive Blvd & E Jefferson St',
#  'Stanton Square SE',
#  'Woodglen Dr & Executive Blvd',
#  'Fleet St & Waterfront St',
#  'Key West Ave & Diamondback Dr',
#  '14th & L St NW',
#  'Massachusetts Ave & Dupont Circle NW',
#  'Amherst Ave & Prichard Rd',
#  'Massachusetts Ave & 6th St NE',
#  'GMU / Fairfax Dr & Kenmore St',
#  'Calvert St & Woodley Pl NW',
#  'Tanger Outlets',
#  'Georgia & Missouri Ave NW',
#  '10th & G St NW',
#  'Mount Vernon Ave & Bruce St',
#  'Eads St & 12th St S',
#  'Georgia Ave & Kennedy St NW',
#  'Columbus Ave & Gramercy Blvd',
#  '61st St & Banks Pl NE',
#  'John McCormack Rd NE',
#  'Baltimore Ave & Van Buren St / Riverdale Park Station',
#  'Spring Hill Metro',
#  'Pleasant St & MLK Ave SE',
#  'Wilson Blvd & N Troy St',
#  'Columbus Circle / Union Station',
#  'Fishers Ln & Rock Creek Mill Rd',
#  'Lincoln Park / 13th & East Capitol St NE ',
#  'Norfolk Ave & Fairmont St',
#  '19th & E Street NW',
#  '1st & M St SE',
#  '18th St & Rhode Island Ave NE',
#  'Ohio Dr & West Basin Dr SW / MLK & FDR Memorials',
#  '14th & D St NW / Ronald Reagan Building',
#  '14th St Heights / 14th & Crittenden St NW',
#  '14th & Belmont St NW',
#  '4th & East Capitol St NE',
#  '19th St & Pennsylvania Ave NW',
#  'Westpark Dr & Leesburg Pike',
#  '7th & S St NW',
#  'D St & Maryland Ave NE',
#  'Anacostia Metro',
#  'N Roosevelt St & Roosevelt Blvd',
#  'Montgomery Ave & Waverly St ',
#  '14th St & Spring Rd NW',
#  '39th & Veazey St NW',
#  'Jones Branch Drive & Scotts Crossing Rd',
#  '1st & D St SE',
#  'Carroll & Ethan Allen Ave',
#  '15th & P St NW',
#  '14th St & New York Ave NW',
#  '17th & G St NW',
#  '15th St & Constitution Ave NW',
#  'Citadel Ave & McGrath Blvd',
#  'Mount Vernon Ave & E Nelson Ave',
#  'M St & New Jersey Ave SE',
#  '14th St & Colorado Ave NW',
#  'USDA / 12th & C St SW',
#  'New Hampshire Ave & East-West Hwy',
#  '16th & R St NW',
#  '11th & O St NW',
#  'Key West Ave & Siesta Key Way',
#  '6th & K St NE',
#  '5th & Kennedy St NW',
#  '22nd & P ST NW',
#  'Georgetown Harbor / 30th St NW',
#  'Rhode Island Ave & 39th St / Brentwood Arts Exchange',
#  '24th & N St NW',
#  'N Lynn St & Fairfax Dr',
#  'Shady Grove Metro West',
#  'W Columbia St & N Washington St',
#  'Rockville Pike & Old Georgetown Rd',
#  'New Hampshire Ave & 24th St NW',
#  '3rd & H St NW',
#  'Gallaudet / 8th St & Florida Ave NE',
#  'Tysons West Transit Center',
#  'Kingman Island/The Fields at RFK',
#  'Washington Blvd & 10th St N',
#  '15th & East Capitol St NE',
#  'McLean Metro',
#  'King St Metro South',
#  'Town Center Pkwy & Bowman Towne Dr',
#  '2nd & G St NE',
#  'Eads St & 15th St S',
#  'Kansas Ave & Sherman Cr NW',
#  '5th & K St NW',
#  'Metro Center / 12th & G St NW',
#  '11th & Girard St NW',
#  '12th St & Pennsylvania Ave SE',
#  'Fort Totten Metro',
#  'Market Square / King St & Royal St',
#  'N Quincy St & Glebe Rd',
#  'Potomac Greens Dr & Slaters Ln',
#  'Adams Mill & Columbia Rd NW',
#  '10th & U St NW',
#  'Washington Blvd & Walter Reed Dr ',
#  '17th & Upshur St NW',
#  'Lyttonsville Rd & Lyttonsville Pl',
#  'Maryland Ave & 17th St NE',
#  'Eckington Pl & Q St NE',
#  'Monroe St & Monroe Pl',
#  'Duke St & John Carlyle St',
#  '1st & O St NW',
#  'Connecticut Ave & Chevy Chase Lake Dr',
#  'East West Hwy & 16th St',
#  'Benning Branch Library',
#  'Potomac Ave & Main Line Blvd',
#  'Sligo Ave & Carroll Ln',
#  'New Jersey Ave & F St NW',
#  'Philadelphia & Maple Ave',
#  '3rd & Elm St NW',
#  '17th St & Independence Ave SW',
#  'Commerce St & Fayette St',
#  '18th St & Wyoming Ave NW',
#  'Georgia & New Hampshire Ave NW',
#  'Oklahoma Ave & D St NE',
#  '11th & M St NW',
#  '17th St & Massachusetts Ave NW',
#  '11th & H St NE',
#  'Takoma Park Rec Center',
#  'California St & Florida Ave NW',
#  'Army Navy Dr & S Nash St',
#  'Columbia Pike & S Courthouse Rd',
#  'Columbia Rd & Belmont St NW',
#  '11th & Kenyon St NW',
#  '20th & O St NW / Dupont South',
#  '14th & Harvard St NW',
#  '4th & W St NE',
#  '21st St & Constitution Ave NW',
#  'State Theatre / Park Pl & N Washington St',
#  '1st & S Capitol St SE / Oxon Run Trail',
#  'Queens Chapel & Hamilton St',
#  'Braddock Rd Metro',
#  '14th & Irving St NW',
#  '3rd & H St NE',
#  '14th & R St NW',
#  'Vermont Ave & I St NW',
#  'Tysons One Pl & Chain Bridge Rd',
#  'Fleet St & Ritchie Pkwy',
#  'Anacostia Ave & Benning Rd NE / River Terrace ',
#  '1st & Washington Hospital Center NW',
#  'Fessenden St & Wisconsin Ave NW',
#  'Bladensburg Rd & Benning Rd NE',
#  'Good Hope & Naylor Rd SE',
#  'Shady Grove Metro East',
#  'Clarendon Metro / Wilson Blvd & N Highland St',
#  'Minnesota Ave Metro/DOES',
#  '36th & Calvert St NW / Glover Park',
#  '12th & Irving St NE',
#  'West Falls Church Metro',
#  '14th & Upshur St NW',
#  'Carlin Springs Rd & N Thomas St',
#  'Constitution Ave & 2nd St NW/DOL',
#  'New Hampshire Ave & T St NW',
#  'Largo Town Center Metro',
#  'Trinidad Rec Center',
#  'Henry St & Pendleton St',
#  '1st & K St SE',
#  '1st & H St NW',
#  'E Fairfax St & S Washington St',
#  'Merrilee Dr & Lauren Elizabeth Lane',
#  'Good Hope Rd & 14th St SE',
#  '11th & F St NW',
#  '3rd & Tingey St SE',
#  'Woodley Park Metro / Calvert St & Connecticut Ave NW',
#  '3rd St & Pennsylvania Ave SE',
#  '22nd & H St NW',
#  '14th & G St NW',
#  'Commonwealth Ave & Oak St',
#  '14th & Girard St NW',
#  '11th & S St NW',
#  'Garland Ave & Walden Rd',
#  '13th St & New York Ave NW',
#  'Wilson Blvd & N Edgewood St',
#  '6th St & Indiana Ave NW',
#  'Potomac & Pennsylvania Ave SE',
#  'New York Ave & 15th St NW',
#  'M St & Pennsylvania Ave NW',
#  'Windham Ln & Amherst Ave',
#  '22nd & I St NW / Foggy Bottom',
#  'Congress Heights Metro',
#  '4th & M St SW',
#  'TJ Cmty Ctr / 2nd St & S Old Glebe Rd',
#  '17th & K St NW / Farragut Square',
#  'Maine Ave & 7th St SW',
#  'Fallsgrove Dr & W Montgomery Ave',
#  'Glebe Rd & 11th St N',
#  'Edgewood Rec Center',
#  'Thomas Circle',
#  'Georgia Ave & Piney Branch Rd NW',
#  'Baltimore Ave & Jefferson St',
#  'Temporary Rd & Old Reston Ave',
#  '18th & M St NW',
#  'Amherst Ave & Elkins St',
#  '25th St & Pennsylvania Ave NW',
#  'Florida Ave & R St NW',
#  'New Jersey Ave & R St NW',
#  '3rd & Underwood St NW',
#  'Monroe Ave & Leslie Ave',
#  '7th & T St NW',
#  '7th & E St SW',
#  '20th St & Virginia Ave NW',
#  'Maple & Ritchie Ave',
#  'Columbia Pike & S Orme St',
#  'Wisconsin Ave & Brandywine St NW',
#  '15th & W St NW',
#  'Branch & Pennsylvania Ave SE',
#  'Hyattsville Library / Adelphi Rd & Toledo Rd',
#  'Virginia Ave & 25th St NW',
#  'Cordell & Norfolk Ave',
#  '10th & Monroe St NE',
#  'Barcroft Community Center',
#  '14th & V St NW',
#  'Powhatan St & Bashford Ln',
#  'Jefferson Dr & 14th St SW',
#  'Connecticut Ave & R St NW',
#  '24th & R St NE / National Arboretum',
#  'Wisconsin Ave & O St NW',
#  'George Mason Dr & Wilson Blvd',
#  'North Capitol St & F St NW',
#  'Greensboro & International Dr',
#  'Rolfe St & 9th St S',
#  'Nannie Helen Burroughs & Minnesota Ave NE',
#  'Montgomery & East Ln',
#  'Nannie Helen Burroughs Ave & 49th St NE',
#  'Oglethorpe St & 42nd Ave',
#  'Friendship Blvd & Willard Ave',
#  'Chillum Rd & Riggs Rd / Riggs Plaza',
#  'Prince St & Union St',
#  'Kennebec St & 11th St N',
#  'Henry Bacon Dr & Lincoln Memorial Circle NW',
#  'Potomac & M St NW',
#  'Reston Town Center Transit Station',
#  'Potomac Ave & Half St SW',
#  'Medical Center Metro ',
#  'Congressional Ln & E Jefferson St',
#  '3rd & D St SE',
#  '15th & L St NW',
#  'Alabama Ave & Stanton Rd SE / Shops at Park Village',
#  'Rhode Island & Connecticut Ave NW',
#  '19th & K St NW',
#  'King St & Patrick St',
#  'Pennsylvania & Minnesota Ave SE',
#  'S Arlington Mill Dr & Campbell Ave',
#  'North Capitol St & G Pl NE',
#  'North Capitol & R St NE',
#  '20th & L St NW',
#  'Connecticut & Nebraska Ave NW',
#  '6th & H St NE',
#  '14th & Otis Pl NW',
#  'New Dominion Pkwy & Fountain Dr',
#  'King Greenleaf Rec Center',
#  'Merrifield Cinema & Merrifield Town Center',
#  'Fairfax Village',
#  'Yuma St & Tenley Circle NW',
#  'Georgia Ave and Fairmont St NW',
#  'Division Ave & Foote St NE',
#  'Rhode Island Ave & V St NE',
#  '18th St & Pennsylvania Ave NW',
#  'Barton St & 10th St N',
#  'Park Rd & Holmead Pl NW',
#  '4th St & Mississippi Ave SE',
#  'S Maple Ave & S Washington St',
#  '21st St & Pennsylvania Ave NW',
#  '15th St & Massachusetts Ave SE',
#  'Georgia Ave & Morton St NW',
#  '8th & D St NW',
#  '2nd St & Seaton Pl NE',
#  'Tenleytown / Wisconsin Ave & Albemarle St NW',
#  'New Hampshire & Kirklynn Ave',
#  'Piccard & W Gude Dr',
#  '16th & Q St SE / Anacostia HS',
#  'Offutt Ln & Chevy Chase Dr',
#  'Potomac Ave & 35th St S',
#  "Largo Rd & Campus Way / Prince Georges's Comm Col",
#  '19th & Savannah St SE',
#  'Needwood Rd & Eagles Head Ct']

# %%
from sklearn.model_selection import train_test_split

# %%
bike_model = bike.copy()
bike_model.pop('date')
bike_model.pop('region_name')
bike_model = bike_model[bike.index.isin(c)]
bike_model.shape
# Out:
# (1545258, 14)

# %%
bike_model
# Out:
#                                  percent_full  hour  longitude   latitude  \
# station
# 22nd & H St NW                       0.117647     9 -77.048852  38.898925
# 22nd & H St NW                       0.176471     9 -77.048852  38.898925
# 22nd & H St NW                       0.235294    16 -77.048852  38.898925
# 22nd & H St NW                       0.294118    23 -77.048852  38.898925
# 22nd & H St NW                       0.235294    16 -77.048852  38.898925
# ...                                       ...   ...        ...        ...
# W Columbia St & N Washington St      0.250000    13 -77.166917  38.885621
# W Columbia St & N Washington St      0.250000    11 -77.166917  38.885621
# W Columbia St & N Washington St      0.416667    13 -77.166917  38.885621
# W Columbia St & N Washington St      0.250000    14 -77.166917  38.885621
# W Columbia St & N Washington St      0.166667    10 -77.166917  38.885621
#
#                                  weekend  tavg  tmax  tmin  prcp  snow  \
# station
# 22nd & H St NW                         0    48    62    38  0.00   0.0
# 22nd & H St NW                         0    51    58    44  0.01   0.0
# 22nd & H St NW                         0    50    54    43  0.00   0.0
# 22nd & H St NW                         1    43    46    41  0.00   0.0
# 22nd & H St NW                         1    43    46    40  0.50   0.0
# ...                                  ...   ...   ...   ...   ...   ...
# W Columbia St & N Washington St        0    40    55    31  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        0    55    66    45  0.26   0.0
#
#                                  holiday  weekday  month  in_dc
# station
# 22nd & H St NW                         0        1     11      1
# 22nd & H St NW                         0        2     11      1
# 22nd & H St NW                         1        3     11      1
# 22nd & H St NW                         0        5     11      1
# 22nd & H St NW                         0        6     12      1
# ...                                  ...      ...    ...    ...
# W Columbia St & N Washington St        0        3     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        0     12      0
#
# [1545258 rows x 14 columns]

# %%
#bike_model_individual = bike_model.drop(columns = ["longitude", "latitude", "in_dc"])
bike_model_individual = bike_model.copy()
bike_model_individual
# Out:
#                                  percent_full  hour  longitude   latitude  \
# station
# 22nd & H St NW                       0.117647     9 -77.048852  38.898925
# 22nd & H St NW                       0.176471     9 -77.048852  38.898925
# 22nd & H St NW                       0.235294    16 -77.048852  38.898925
# 22nd & H St NW                       0.294118    23 -77.048852  38.898925
# 22nd & H St NW                       0.235294    16 -77.048852  38.898925
# ...                                       ...   ...        ...        ...
# W Columbia St & N Washington St      0.250000    13 -77.166917  38.885621
# W Columbia St & N Washington St      0.250000    11 -77.166917  38.885621
# W Columbia St & N Washington St      0.416667    13 -77.166917  38.885621
# W Columbia St & N Washington St      0.250000    14 -77.166917  38.885621
# W Columbia St & N Washington St      0.166667    10 -77.166917  38.885621
#
#                                  weekend  tavg  tmax  tmin  prcp  snow  \
# station
# 22nd & H St NW                         0    48    62    38  0.00   0.0
# 22nd & H St NW                         0    51    58    44  0.01   0.0
# 22nd & H St NW                         0    50    54    43  0.00   0.0
# 22nd & H St NW                         1    43    46    41  0.00   0.0
# 22nd & H St NW                         1    43    46    40  0.50   0.0
# ...                                  ...   ...   ...   ...   ...   ...
# W Columbia St & N Washington St        0    40    55    31  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        1    50    67    38  0.00   0.0
# W Columbia St & N Washington St        0    55    66    45  0.26   0.0
#
#                                  holiday  weekday  month  in_dc
# station
# 22nd & H St NW                         0        1     11      1
# 22nd & H St NW                         0        2     11      1
# 22nd & H St NW                         1        3     11      1
# 22nd & H St NW                         0        5     11      1
# 22nd & H St NW                         0        6     12      1
# ...                                  ...      ...    ...    ...
# W Columbia St & N Washington St        0        3     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        5     12      0
# W Columbia St & N Washington St        0        0     12      0
#
# [1545258 rows x 14 columns]

# %%
X_train_i, X_test_i, y_train_i, y_test_i = train_test_split(bike_model_individual.iloc[:,1:], bike_model_individual.iloc[:,0], test_size = 0.3, random_state = 0, stratify = bike_model_individual.index)

# %%
X_train_i[X_train_i.index == c[0]]
# Out:
#                 hour  longitude   latitude  weekend  tavg  tmax  tmin  prcp  \
# station
# 23rd & M St NW    13 -77.050264  38.905303        0    80    91    71  0.00
# 23rd & M St NW    20 -77.050264  38.905303        0    83    90    72  0.00
# 23rd & M St NW    13 -77.050264  38.905303        1    78    85    66  0.00
# 23rd & M St NW    16 -77.050264  38.905303        0    53    64    44  0.00
# 23rd & M St NW    18 -77.050264  38.905303        0    67    79    57  0.00
# ...              ...        ...        ...      ...   ...   ...   ...   ...
# 23rd & M St NW    12 -77.050264  38.905303        1    68    77    63  0.00
# 23rd & M St NW     5 -77.050264  38.905303        1    73    86    63  0.00
# 23rd & M St NW     4 -77.050264  38.905303        1    76    85    67  0.01
# 23rd & M St NW     6 -77.050264  38.905303        0    58    70    50  0.00
# 23rd & M St NW    16 -77.050264  38.905303        0    56    61    50  0.00
#
#                 snow  holiday  weekday  month  in_dc
# station
# 23rd & M St NW   0.0        0        3      8      1
# 23rd & M St NW   0.0        0        0      7      1
# 23rd & M St NW   0.0        0        5      8      1
# 23rd & M St NW   0.0        0        1     11      1
# 23rd & M St NW   0.0        0        4      6      1
# ...              ...      ...      ...    ...    ...
# 23rd & M St NW   0.0        0        6      4      1
# 23rd & M St NW   0.0        0        5      9      1
# 23rd & M St NW   0.0        0        6      6      1
# 23rd & M St NW   0.0        0        4     10      1
# 23rd & M St NW   0.0        0        3     10      1
#
# [4742 rows x 13 columns]

# %%
X_test_i[X_test_i.index == c[0]]
# Out:
#                 hour  longitude   latitude  weekend  tavg  tmax  tmin  prcp  \
# station
# 23rd & M St NW    12 -77.050264  38.905303        1    38    43    35  0.07
# 23rd & M St NW    15 -77.050264  38.905303        0    81    94    72  0.00
# 23rd & M St NW    23 -77.050264  38.905303        0    64    74    55  0.00
# 23rd & M St NW    15 -77.050264  38.905303        1    73    86    63  0.00
# 23rd & M St NW    19 -77.050264  38.905303        0    46    52    44  0.75
# ...              ...        ...        ...      ...   ...   ...   ...   ...
# 23rd & M St NW    16 -77.050264  38.905303        1    84    92    74  0.72
# 23rd & M St NW     2 -77.050264  38.905303        0    63    73    50  0.00
# 23rd & M St NW     5 -77.050264  38.905303        1    80    91    70  0.00
# 23rd & M St NW    13 -77.050264  38.905303        0    83    98    73  0.00
# 23rd & M St NW     8 -77.050264  38.905303        0    58    71    51  0.00
#
#                 snow  holiday  weekday  month  in_dc
# station
# 23rd & M St NW   0.0        0        5      3      1
# 23rd & M St NW   0.0        0        0      9      1
# 23rd & M St NW   0.0        0        0      4      1
# 23rd & M St NW   0.0        0        5      9      1
# 23rd & M St NW   0.0        0        0     12      1
# ...              ...      ...      ...    ...    ...
# 23rd & M St NW   0.0        0        5      7      1
# 23rd & M St NW   0.0        0        1     10      1
# 23rd & M St NW   0.0        0        5      8      1
# 23rd & M St NW   0.0        0        2     10      1
# 23rd & M St NW   0.0        0        4      3      1
#
# [2033 rows x 13 columns]

# %% [markdown]
# ## Approach 1 - fitting individual stations and assessing performance
#
# note that location based features were dropped (latitude, longitude, and in_DC) were dropped since these are constant variables when modeling on each station, and so do not help to improve the predictive power of the model.

# %% [markdown]
# ### linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
tmp_train = X_train_i.drop(columns = ["longitude", "latitude", "in_dc"])
tmp_test = X_test_i.drop(columns = ["longitude", "latitude", "in_dc"])
def error_regression(station_id):
    regressor = LinearRegression()
    regressor.fit(tmp_train[tmp_train.index == station_id], y_train_i[tmp_train.index == station_id])
    y_pred = regressor.predict(tmp_test[tmp_test.index == station_id])
    return mean_squared_error(y_test_i[tmp_test.index == station_id], y_pred)

# %%
accuracy_scores = []
for i in range(len(c)):
    accuracy_scores.append(error_regression(c[i]))

# %%
np.array(accuracy_scores)[np.logical_or(np.array(accuracy_scores) < 0,np.array(accuracy_scores) > 1)]
# Out:
# array([], dtype=float64)

# %%
#pd.Series(np.array(accuracy_scores)[np.where(np.array(accuracy_scores) < 0.1)]).describe()
pd.Series(accuracy_scores).describe()
# Out:
# count    475.000000
# mean       0.048318
# std        0.020522
# min        0.008402
# 25%        0.033160
# 50%        0.047422
# 75%        0.063986
# max        0.098451
# dtype: float64

# %%
plt.hist(np.sqrt(np.array(accuracy_scores)), bins = "auto", alpha = 0.7, rwidth = 0.9)
plt.grid(axis = "y")
plt.title("Distribution of model testing MSE by station (median RMSE = " + str(round(np.median(np.sqrt(np.array(accuracy_scores))),4)) + ')')
plt.xlabel("Accuracy")
plt.ylabel("Station Count")
plt.show()

# %% [markdown]
# ### random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
## fitting a basic model without cross-validation
def error_regression_rf(station_id):
    regressor = RandomForestRegressor(n_estimators = 50, random_state = 0, max_depth = 5)
    regressor.fit(tmp_train[tmp_train.index == station_id], y_train_i[tmp_train.index == station_id])
    y_pred = regressor.predict(tmp_test[tmp_test.index == station_id])
    return mean_squared_error(y_test_i[tmp_test.index == station_id], y_pred)

# %%
accuracy_scores_rf = []
for i in range(len(c)):
    accuracy_scores_rf.append(error_regression_rf(c[i]))

# %%
np.array(accuracy_scores_rf)[np.logical_or(np.array(accuracy_scores_rf) < 0,np.array(accuracy_scores_rf) > 1)]
# Out:
# array([], dtype=float64)

# %%
plt.hist(np.sqrt(np.array(accuracy_scores_rf)), bins = "auto", alpha = 0.7, rwidth = 0.9)
plt.grid(axis = "y")
plt.title("Distribution of model testing MSE by station (median MSE = " + str(round(np.median(np.sqrt(np.array(accuracy_scores_rf))),4)) + ')')
plt.xlabel("Accuracy")
plt.ylabel("Station Count")
plt.show()

# %%
round(pd.Series(accuracy_scores_rf).describe(), 4)
# Out:
# count    475.0000
# mean       0.0309
# std        0.0137
# min        0.0048
# 25%        0.0207
# 50%        0.0317
# 75%        0.0412
# max        0.0628
# dtype: float64

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
def error_regression_xgb(station_id):
    regressor = xgb.XGBRegressor(max_depth = 5, n_estimators = 50)
    regressor.fit(tmp_train[tmp_train.index == station_id], y_train_i[tmp_train.index == station_id])
    y_pred = regressor.predict(tmp_test[tmp_test.index == station_id])
    return mean_squared_error(y_test_i[tmp_test.index == station_id], y_pred)

# %%
accuracy_scores_xgb = []
for i in range(len(c)):
    accuracy_scores_xgb.append(error_regression_xgb(c[i]))

# %%
np.array(accuracy_scores_xgb)[np.logical_or(np.array(accuracy_scores_xgb) < 0,np.array(accuracy_scores_xgb) > 1)]
# Out:
# array([], dtype=float64)

# %%
plt.hist(np.sqrt(np.array(accuracy_scores_xgb)), bins = "auto", alpha = 0.7, rwidth = 0.9)
plt.grid(axis = "y")
plt.title("Distribution of model testing RMSE by station") # (median RMSE = " + str(round(np.mean(np.sqrt(np.array(accuracy_scores_xgb))),4)) + ')')
plt.xlabel("RMSE")
plt.ylabel("Station Count")
plt.show()

# %%
(pd.Series(accuracy_scores_xgb) ** (1/2)).describe()
# Out:
# count    475.000000
# mean       0.128620
# std        0.029091
# min        0.050766
# 25%        0.107254
# 50%        0.128306
# 75%        0.150360
# max        0.213382
# dtype: float64

# %%
.1286 + 2 * .029
# Out:
# 0.1866

# %%
.1286 - 2 * .029
# Out:
# 0.0706

# %%
.13*16
# Out:
# 2.08

# %%
reg_scores_df = pd.DataFrame(data = [*zip(accuracy_scores, accuracy_scores_rf, accuracy_scores_xgb)], index = c, columns = ['lr', 'rf', 'xgb'])\
.melt(var_name = 'model', value_name = 'mse', ignore_index = False)
reg_scores_df["rmse"] = reg_scores_df["mse"] ** (1/2)
sns.histplot(data = reg_scores_df, x = 'rmse', hue = 'model', stat = 'probability', alpha = 0.5)
plt.show()

# %%
sns.boxplot(data = reg_scores_df, x = "model", y = "rmse")
plt.show()

# %%
import matplotlib.image as mpimg
dc_img=mpimg.imread('unknown.png')

# %%
len(accuracy_scores_xgb)
# Out:
# 475

# %%
reg_scores_df[reg_scores_df.model == "xgb"].shape
# Out:
# (475, 3)

# %%
reg_scores_df[reg_scores_df.model == "xgb"][["rmse"]]
# Out:
#                                         rmse
# 23rd & M St NW                      0.147876
# Reston Town Center Transit Station  0.108874
# 4th & W St NE                       0.137369
# Van Ness Metro / UDC                0.122812
# Connecticut Ave & Tilden St NW      0.133903
# ...                                      ...
# Pennsylvania & Minnesota Ave SE     0.116496
# 1st & D St SE                       0.162924
# 20th St & Florida Ave NW            0.183480
# New Hampshire Ave & 24th St NW      0.155097
# N Quincy St & Glebe Rd              0.154742
#
# [475 rows x 1 columns]

# %%
X_test_i[["longitude", "latitude", "in_dc"]].drop_duplicates()
# Out:
#                                                    longitude   latitude  in_dc
# station
# 19th St & Pennsylvania Ave NW                     -77.042900  38.900300      1
# 4th & W St NE                                     -77.000648  38.919077      1
# New Jersey Ave & N St NW/Dunbar HS                -77.015360  38.907333      1
# 23rd & E St NW                                    -77.049882  38.896104      1
# Columbia Rd & Georgia Ave NW                      -77.023795  38.928121      1
# ...                                                      ...        ...    ...
# The Mall at Prince Georges                        -76.954171  38.968842      0
# Greensboro & International Dr                     -77.227417  38.923083      0
# Key West Ave & Diamondback Dr                     -77.202354  39.106152      0
# Riggs Rd & East West Hwy                          -76.980700  38.972500      0
# Largo Rd & Campus Way / Prince Georges's Comm Col -76.825535  38.889940      0
#
# [475 rows x 3 columns]

# %%
X_test_i.groupby(X_test_i.index)[["longitude", "latitude", "in_dc"]].min()
# Out:
# (488, 3)

# %%
xgb_plotter = reg_scores_df[reg_scores_df.model == "xgb"][["rmse"]]\
.merge(X_test_i[["longitude", "latitude", "in_dc"]].drop_duplicates(), how = "inner", right_index = True, left_index = True)
xgb_plotter
# Out:
#                                         rmse  longitude   latitude  in_dc
# 23rd & M St NW                      0.147876 -77.050264  38.905303      1
# Reston Town Center Transit Station  0.108874 -77.359718  38.957037      0
# 4th & W St NE                       0.137369 -77.000648  38.919077      1
# Van Ness Metro / UDC                0.122812 -77.063896  38.944551      1
# Connecticut Ave & Tilden St NW      0.133903 -77.061977  38.941139      1
# ...                                      ...        ...        ...    ...
# Pennsylvania & Minnesota Ave SE     0.116496 -76.971015  38.873057      1
# 1st & D St SE                       0.162924 -77.005965  38.884916      1
# 20th St & Florida Ave NW            0.183480 -77.044600  38.915400      1
# New Hampshire Ave & 24th St NW      0.155097 -77.051084  38.901755      1
# N Quincy St & Glebe Rd              0.154742 -77.107735  38.876393      0
#
# [475 rows x 4 columns]

# %%
reg_scores_df.groupby("model")["rmse"].describe()
# Out:
#        count      mean       std       min       25%       50%       75%  \
# model
# lr     475.0  0.214245  0.049220  0.091664  0.182097  0.217767  0.252955
# rf     475.0  0.170695  0.042075  0.068976  0.143725  0.178012  0.202976
# xgb    475.0  0.128620  0.029091  0.050766  0.107254  0.128306  0.150360
#
#             max
# model
# lr     0.313770
# rf     0.250689
# xgb    0.213382

# %%
reg_scores_df.groupby("model")["rmse"].median()
# Out:
# model
# lr     0.217767
# rf     0.178012
# xgb    0.128306
# Name: rmse, dtype: float64

# %%
str(round(np.mean(np.sqrt(np.array(accuracy_scores_xgb))),4))
# Out:
# '0.1286'

# %%
plt.figure(figsize=(20,8))
ax = plt.scatter(x = "longitude", data = xgb_plotter, y = "latitude", c = "rmse",
            cmap = plt.get_cmap("ocean"), alpha = 0.9)
plt.colorbar(ax, label ="RMSE by station")
#plt.title("Average error across all models is roughly " + str(round(np.mean(np.sqrt(np.array(accuracy_scores_xgb))),4)*100) + "%") 
plt.xlim(-77.369,-76.825)
# The range of y-axis is the range of latitude of this map.
plt.ylim(38.75,39.15)
# Overlap the scatterplot on top of the DC map.
plt.imshow(dc_img, alpha=0.9, extent=[-77.369, -76.825, 38.75, 39.15])
plt.xticks([])
plt.yticks([])
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Approach 2 - fit all data to single model and assess performance

# %%
bike_model.shape
# Out:
# (1545258, 14)

# %%
bike_model.columns
# Out:
# Index(['percent_full', 'hour', 'longitude', 'latitude', 'weekend', 'tavg',
#        'tmax', 'tmin', 'prcp', 'snow', 'holiday', 'weekday', 'month', 'in_dc'],
#       dtype='object')

# %%
bike_model.head()
# Out:
#                 percent_full  hour  longitude   latitude  weekend  tavg  tmax  \
# station
# 22nd & H St NW      0.117647     9 -77.048852  38.898925        0    48    62
# 22nd & H St NW      0.176471     9 -77.048852  38.898925        0    51    58
# 22nd & H St NW      0.235294    16 -77.048852  38.898925        0    50    54
# 22nd & H St NW      0.294118    23 -77.048852  38.898925        1    43    46
# 22nd & H St NW      0.235294    16 -77.048852  38.898925        1    43    46
#
#                 tmin  prcp  snow  holiday  weekday  month  in_dc
# station
# 22nd & H St NW    38  0.00   0.0        0        1     11      1
# 22nd & H St NW    44  0.01   0.0        0        2     11      1
# 22nd & H St NW    43  0.00   0.0        1        3     11      1
# 22nd & H St NW    41  0.00   0.0        0        5     11      1
# 22nd & H St NW    40  0.50   0.0        0        6     12      1

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
mean_squared_error(y_test, y_pred) ** (1/2)
# Out:
# 0.2557214462480275

# %% [markdown]
# ## XGBoost

# %%
## xgb training matrix
# "binary:logistic"
params = {"objective":"reg:linear","max_depth":5, "colsample_bytree": 0.3, "n_estimators": 100}
dmatrix = xgb.DMatrix(data = X_train, label = y_train)

# %%
xg_reg = xgb.train(params=params, dtrain=dmatrix)
y_pred = xg_reg.predict(xgb.DMatrix(X_test))
mean_squared_error(y_test, y_pred) ** (1/2)
# Out:
# [17:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [17:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# 0.2505918693692099

# %%
cv_results = xgb.cv(dtrain = dmatrix, params = params, nfold =3, num_boost_round = 100,
                   early_stopping_rounds = 10, as_pandas = True, seed = 123)
# Out:
# [17:47:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [17:47:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:47:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [17:47:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:47:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [17:47:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
from sklearn.model_selection import RandomizedSearchCV
# Create the parameter grid
xgb_model = xgb.XGBRegressor()
param_grid = {'learning_rate': np.linspace(0.1, 2, 150),
              'n_estimators': [*range(50,201, 25)],
              'max_depth': list(*range[2,6]))} 

# Create a random search object
rand_xgb = RandomizedSearchCV(
    estimator = xgb_model,
    param_distributions = param_grid,
    n_iter = 10,
    n_jobs=4,
    cv = 3,
    refit=True)

# %%
# Fit to the training data
rand_xgb.fit(X_train, y_train)
y_pred = rand_xgb.predict(X_test)
mean_squared_error(y_test,y_pred) ** (1/2)
# Out:
# [18:35:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "min_samples_leaf" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# 0.19915852466598852

# %%
rand_xgb.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_leaf': 58,
#  'learning_rate': 0.7375838926174496}

# %%
## xgb training matrix
# "binary:logistic"
params = rand_xgb.best_params_
dmatrix = xgb.DMatrix(data = X_train, label = y_train)
xg_reg = xgb.train(params=params, dtrain=dmatrix)
plt.rcParams['figure.figsize'] = [7,7]
xgb.plot_importance(xg_reg,
                    importance_type = "weight",
                    title = "Location and time variables are most important features in model",
                   xlabel = "Feature importance by weight")
# metric that simply sums up how many times each feature is split on
plt.show()
# Out:
# [18:58:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "min_samples_leaf", "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
## performance by station for single model
test_df = X_test.copy()
test_df["actual"] = y_test
test_df["predicted"] = y_pred
test_df["sq_error"] = (test_df["actual"] - test_df["predicted"]) ** 2

# %%
station_rmse = pd.DataFrame((test_df.groupby(test_df.index)["sq_error"].mean() ** (1/2)))

# %%
tmp = test_df[["latitude", "longitude", "in_dc"]].drop_duplicates()

# %%
set(station_rmse.index).difference(set(tmp.index))
# Out:
# set()

# %%
one_mod_plotter = station_rmse.merge(tmp, how = "inner", right_index = True, left_index = True).rename(columns = {"sq_error":"RMSE"})
one_mod_plotter
# Out:
#                                                         RMSE   latitude  \
# station
# 10th & E St NW                                      0.246620  38.895914
# 10th & Florida Ave NW                               0.216985  38.920387
# 10th & G St NW                                      0.220759  38.898243
# 10th & K St NW                                      0.243406  38.902400
# 10th & Monroe St NE                                 0.243009  38.932514
# ...                                                      ...        ...
# Wisconsin Ave & O St NW                             0.201972  38.908490
# Woodglen Dr & Executive Blvd                        0.230710  39.043170
# Woodley Park Metro / Calvert St & Connecticut A...  0.234811  38.923389
# Woodmont Ave & Strathmore St                        0.250940  38.979875
# Yuma St & Tenley Circle NW                          0.229092  38.946182
#
#                                                     longitude  in_dc
# station
# 10th & E St NW                                     -77.026064    1.0
# 10th & Florida Ave NW                              -77.025672    1.0
# 10th & G St NW                                     -77.026235    1.0
# 10th & K St NW                                     -77.026220    1.0
# 10th & Monroe St NE                                -76.992889    1.0
# ...                                                       ...    ...
# Wisconsin Ave & O St NW                            -77.063586    1.0
# Woodglen Dr & Executive Blvd                       -77.113500    0.0
# Woodley Park Metro / Calvert St & Connecticut A... -77.051833    1.0
# Woodmont Ave & Strathmore St                       -77.093522    0.0
# Yuma St & Tenley Circle NW                         -77.080590    1.0
#
# [488 rows x 4 columns]

# %%
one_mod_plotter.RMSE.describe()
# Out:
# count    475.000000
# mean       0.214935
# std        0.033134
# min        0.104048
# 25%        0.194888
# 50%        0.217696
# 75%        0.238010
# max        0.358922
# Name: RMSE, dtype: float64

# %%
plt.figure(figsize=(20,8))
ax = plt.scatter(x = "longitude", data = one_mod_plotter, y = "latitude", c = "RMSE", #label = one_mod_plotter.index,
            cmap = plt.get_cmap("jet"), alpha = 0.9)
plt.colorbar(ax, label ="Predictive accuracy per station")
#plt.title('No pattern in predictive accuracy based on clusters of stations')
plt.legend()
plt.xlim(-77.369,-76.825)
# The range of y-axis is the range of latitude of this map.
plt.ylim(38.75,39.15)
# Overlap the scatterplot on top of the DC map.
plt.imshow(dc_img, alpha=0.9, extent=[-77.369, -76.825, 38.75, 39.15])
plt.xticks([])
plt.yticks([])
plt.ylabel('')
plt.show()
